# %%
import tensorflow as tf
import scipy
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
from scipy import signal
from scipy.fft import fftshift

# %%
def loading_wav_data(file_path,channel):
    sample_rate,data = wavfile.read(file_path)
    ch1 =np.swapaxes(data,1,0)[0]
    ch2 =np.swapaxes(data,1,0)[1]
    if channel == 'ch1':
        return ch1,sample_rate
    else:
        return ch2,sample_rate

# %%
sample_freq,data2 = wavfile.read('1_10132.wav','ch1')

# %%
sample_freq
# Out:
# 48000

# %%
data2
# Out:
# memmap([-61, -40, -49, ...,   0,   0,   0], dtype=int16)

# %%
fft = scipy.fft.fft(data2)

# %%
plt.plot(fft)

# %%
f, t, Sxx = signal.spectrogram(data2, sample_freq)

# %%
f1 = np.array(f)

# %%
f_max = np.amax(f1)

# %%
f_max
# Out:
# 22050.0

# %%
sxx = np.array(Sxx)

# %%
f.shape
# Out:
# (129,)

# %%
Sxx.shape
# Out:
# (129, 984)

# %%
plt.pcolormesh(t, f, Sxx, shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.ylim()
plt.xlabel('Time [sec]')
plt.show()

# %%
sample_rate, data = loading_wav_data('1_10101.wav','ch1')

# %%
data
# Out:
# 44100

# %%
f, t, Sxx = signal.spectrogram(x, fs)
plt.pcolormesh(t, f, Sxx, shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
def spectogram(signal):
    f, t, Sxx = signal.spectrogram(x, fs)
    plt.pcolormesh(t, f, Sxx, shading='gouraud')
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    plt.show()

# %%
data = loading_wav_data('1_10101.wav','ch1')

# %%
data
# Out:
# array([-139, -193, -206, ...,    0,    0,    0], dtype=int16)

# %%
plt.plot(data)

# %%
#maximums
#time between two maximums
#
